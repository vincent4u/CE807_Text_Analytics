# %% [markdown]
# <a href="https://colab.research.google.com/github/vincent4u/CE807_Text_Analytics/blob/main/Another_copy_of_Assignment_code12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Student ID: 2314555
# Vincent Nnamdi UGWAH

# %% [markdown]
# Installing all required libraries.

# %%
import numpy as np
import os
import pickle
import pandas as pd
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
from sklearn.metrics import confusion_matrix

import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import nltk
import re
from tqdm import tqdm

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# **student id input as a variable for seeding**

# %%
student_id = 2314555  #my student reg number

# %% [markdown]
# Let's set `seed` for all libraries like `torch`, `numpy` etc as my student id

# %%
# setting studen_id as same seeds for all libraries

#numpy seed
np.random.seed(student_id)

# %% [markdown]
# # Common Codes
#
# This section includes all common codes, for examples
#
#
# *   Data read
# *   Command Line argument reading
# *   Performance Matrics
# *   Print Dataset Statistics
# *   Saving model and output
# *   Loading Model and output
# *   etc

# %% [markdown]
# **Setting first the GDrive to access and set data and model paths**
#
# For examples,
#
# student_id = 12345670
#
# set GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = ‘./CE807-24-SP/Lab10/’ in your GDrive
#
# now set all global variable,
#
#
# Sample output directory and file structure: https://drive.google.com/drive/folders/1okgSzgGiwPYYFp7NScEt9MNVolOlld1d?usp=share_link

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# Initializing GDrive and data and models paths

GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = './CE807-24-SP/Assignment/'
GOOGLE_DRIVE_PATH = os.path.join('gdrive', 'MyDrive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
print('List files: ', os.listdir(GOOGLE_DRIVE_PATH))

DATA_PATH = os.path.join(GOOGLE_DRIVE_PATH, 'data', '5') # Directing path to data type 5, since my student numbers ends with 5
train_file = os.path.join(DATA_PATH, 'train.csv')         # Reading the Train CSV file
print('Train file: ', train_file)

val_file = os.path.join(DATA_PATH, 'valid.csv')           # Reading the Validation CSV file
print('Validation file: ', val_file)

test_file = os.path.join(DATA_PATH, 'test.csv')            # Reading the Test CSV file
print('Test file: ', test_file)


MODEL_PATH = os.path.join(GOOGLE_DRIVE_PATH, 'model', str(student_id)) # Making sure to use student Regitration number already called in the begining
MODEL_Gen_DIRECTORY = os.path.join(MODEL_PATH, 'Model_Gen')            # Creating Path to Model Generative directory
print('Model Generative directory: ', MODEL_Gen_DIRECTORY)

MODEL_Gen_File = MODEL_Gen_DIRECTORY + '.zip'


MODEL_Dis_DIRECTORY = os.path.join(MODEL_PATH, 'Model_Dis')           # Creating Path to Model Discriminative directory
print('Model Discriminative directory: ', MODEL_Dis_DIRECTORY)

MODEL_Dis_File = MODEL_Dis_DIRECTORY + '.zip'                         # Zipping the FIle
# Out:
# List files:  ['data', 'model']
# Train file:  gdrive/MyDrive/./CE807-24-SP/Assignment/data/5/train.csv
# Validation file:  gdrive/MyDrive/./CE807-24-SP/Assignment/data/5/valid.csv
# Test file:  gdrive/MyDrive/./CE807-24-SP/Assignment/data/5/test.csv
# Model Generative directory:  gdrive/MyDrive/./CE807-24-SP/Assignment/model/2314555/Model_Gen
# Model Discriminative directory:  gdrive/MyDrive/./CE807-24-SP/Assignment/model/2314555/Model_Dis

# %% [markdown]
# Visualing the train file for possible steps to Preprocessing

# %%
train_df = pd.read_csv(train_file)
train_df.head()
# Out:
#     comment_id                                            comment  split  \
# 0  579986655.0  SDATA_5 :  NEWLINE_TOKENNEWLINE_TOKEN== Kinder...  train
# 1   86029332.0  SDATA_5 :  NEWLINE_TOKENNEWLINE_TOKENDo not vi...  train
# 2  169864624.0  SDATA_5 :  NEWLINE_TOKEN:::Judging by some of ...  train
# 3   96482757.0        SDATA_5 :  I LOVE FATTY SEX MMMM  : EDATA_5  train
# 4  327661902.0  SDATA_5 :  NEWLINE_TOKEN:Please, could you exp...  train
#
#    toxicity
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %% [markdown]
# # ***Computing the Performance Metrics***
# I am going to use different performance matrics like Accuracy, Recall (macro), Precision (macro), F1 (macro) and Confusion Matrix for the performance evaluation. This will print all the matrics and display Confusion Matrix with proper X & Y axis labels

# %%
#Writting the function for the computing the performance metrics

def compute_performance(y_true, y_pred):
    # Computing metrics
    accuracy = accuracy_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred, average='macro')
    precision = precision_score(y_true, y_pred, average='macro')
    f1 = f1_score(y_true, y_pred, average='macro')

    # Print metrics
    print('Accuracy:', accuracy)
    print('Recall (macro):', recall)
    print('Precision (macro):', precision)
    print('F1 Score (macro):', f1)

    # Compute and print confusion matrix
    labels = np.unique(np.concatenate((y_true, y_pred)))
    cm = confusion_matrix(y_true, y_pred, labels=labels)
    print('Confusion Matrix:')
    print(cm)

    return f1

# %% [markdown]
# # ***Saving and Loading Model ***

# %%
def save_model(model,model_dir):
  # save the model to disk
  # Check if the Model directory exists

  if not os.path.exists(model_dir):
      # Creating the directory if it doesn't exist
      os.makedirs(model_dir)
      print(f"Directory '{model_dir}' created successfully.")
  else:
      print(f"Directory '{model_dir}' already exists.")

  model_file = os.path.join(model_dir, 'model.sav')
  pickle.dump(model, open(model_file, 'wb'))

  print('Saved model to ', model_file)

  return model_file

def load_model(model_file):
    # loading model from disk

    model = pickle.load(open(model_file, 'rb'))

    print('Loaded model from ', model_file)

    return model

# %% [markdown]
# # Downloading GDrive Link into a directory

# %%
import requests

def extract_file_id_from_url(url):
    # Extract the file ID from the URL
    file_id = None
    if 'drive.google.com' in url:
        file_id = url.split('/')[-2]
    elif 'https://docs.google.com' in url:
        file_id = url.split('/')[-1]

    return file_id

def download_file_from_drive(file_id, file_path):
    # Constructing the download URL
    download_url = f"https://drive.google.com/uc?id={file_id}"

    # Download the file
    response = requests.get(download_url)
    if response.status_code == 200:
        with open(file_path, 'wb') as f:
            f.write(response.content)
        print("File downloaded successfully!",file_path)
    else:
        print("Failed to download the file.")

def download_zip_file_from_link(file_url,file_path):

  file_id = extract_file_id_from_url(file_url)
  if file_id:
      download_file_from_drive(file_id, file_path)
  else:
      print("Invalid Google Drive URL.")

# %% [markdown]
# # Zip and Unzip a GDrive File

# %%
import zipfile
import shutil
import os

# Function to zip a directory
def zip_directory(directory, zip_filename):
    with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, dirs, files in os.walk(directory):
            for file in files:
                zipf.write(os.path.join(root, file), os.path.relpath(os.path.join(root, file), os.path.join(directory, '..')))
        print('Created a zip file',zip_filename)

# Function to unzip a zip file
def unzip_file(zip_filename, extract_dir):
    with zipfile.ZipFile(zip_filename, 'r') as zip_ref:
        zip_ref.extractall(extract_dir)
    print('Extracted a zip file to',extract_dir)

# Example usage:
# directory_to_zip = 'path/to/your/directory'
# zip_filename = 'output_zipfile.zip'

# # Zip the directory
# zip_directory(directory_to_zip, zip_filename)

# # Unzip the zip file
# extract_dir = 'path/to/extract'
# unzip_file(zip_filename, extract_dir)

# %% [markdown]
# # Get Sharable link of your Zip file in Gdrive

# %%
# !pip install -U -q PyDrive

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials


def get_gdrive_link(file_path):
    # Authenticating and creating PyDrive client
    auth.authenticate_user()
    gauth = GoogleAuth()
    gauth.credentials = GoogleCredentials.get_application_default()
    drive = GoogleDrive(gauth)

    # Find the file in Google Drive
    file_name = file_path.split('/')[-1]
    file_list = drive.ListFile({'q': f"title='{file_name}'"}).GetList()

    # Get the file ID and generate the shareable link
    if file_list:
        file_id = file_list[0]['id']
        gdrive_link = f"https://drive.google.com/file/d/{file_id}/view?usp=sharing"
        return gdrive_link
    else:
        return "File not found in Google Drive"

def get_shareable_link(url):

    file_id = extract_file_id_from_url(url)

    auth.authenticate_user()
    gauth = GoogleAuth()
    gauth.credentials = GoogleCredentials.get_application_default()
    drive = GoogleDrive(gauth)

    try:
        file_obj = drive.CreateFile({'id': file_id})
        file_obj.FetchMetadata()
        file_obj.InsertPermission({
            'type': 'anyone',
            'value': 'anyone',
            'role': 'reader'
        })

        # Getting the shareable link
        return file_obj['alternateLink']
    except Exception as e:
        print("Error:", e)
        return None

# %% [markdown]
# # ***Loading all Libraries***

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import nltk
import re
from tqdm import tqdm

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# # Method Generative Start
#
# This section includes all the details for the Generative Model (Naive Bayes).
# It includes the following:
#
# *   Data reading
# *   Data clearning, if any
# *   Convert data to vector/tokenization/vectorization
# *   Model Declaration/Initialization/building
# *   Training and validation of the model using training and validation dataset
# *   Save the trained model
# *   Load and Test the model on testing set
# *   Save the output of the model

# %% [markdown]
# ## Training Generative Method Code

# %% [markdown]
# # ***Step 1: Data Cleaning and Preprocessing***

# %%
    # Define preprocessing function
    def preprocess_text(text):
        # Remove specific tokens
        text = text.replace("SDATA_5 :", "").replace("EDATA_5", "").replace("NEWLINE_TOKEN", "")
        # Remove special characters and punctuation marks using regular expressions
        text = re.sub(r'[^\w\s]', '', text)
        # Remove URLs, email addresses, and phone numbers
        text = re.sub(r"http\S+|www\S+|\S+@\S+|\d{10}", "", text)
        # Remove numbers
        text = re.sub(r"\d+", "", text)
        # Remove non-ASCII characters
        text = text.encode("ascii", "ignore").decode()
        # Convert the text to lowercase
        text = text.lower()
        # Remove extra white spaces
        text = re.sub(r"\s+", " ", text)
        # Tokenize the text
        tokens = nltk.word_tokenize(text)
        # Remove stop words
        stop_words = set(stopwords.words("english"))
        tokens = [word for word in tokens if word not in stop_words]
        # Apply lemmatization
        lemmatizer = WordNetLemmatizer()
        tokens = [lemmatizer.lemmatize(word) for word in tokens]
        # Join the tokens back into a single string
        preprocessed_text = " ".join(tokens)
        return preprocessed_text

# %% [markdown]
# **Model training, saving and generating link**

# %%
def train_Gen(train_file, val_file, model_dir):

    # reading the train and validation file
    train_df = pd.read_csv(train_file)
    val_df = pd.read_csv(val_file)

    tqdm.pandas(desc="Preprocessing train data")
    train_df['preprocessed_comment'] = train_df['comment'].progress_apply(preprocess_text)
    tqdm.pandas(desc="Preprocessing val data")
    val_df['preprocessed_comment'] = val_df['comment'].progress_apply(preprocess_text)

    # Initialize the vectorizer
    vectorizer = TfidfVectorizer()
    # Fit the vectorizer on the training data and transform the training data
    train_features = vectorizer.fit_transform(train_df['preprocessed_comment'])
    # Transform the validation data using the fitted vectorizer
    val_features = vectorizer.transform(val_df['preprocessed_comment'])

    # Define the Naive Bayes model with TF-IDF vectorizer as a pipeline
    pipeline = Pipeline([
        ('tfidf', vectorizer),
        ('naive_bayes', MultinomialNB())
    ])

    # Defining the hyperparamneters used
    best_params = {
        'naive_bayes__alpha': 0.0010454648682604534,
        'naive_bayes__fit_prior': False,
    }

    #initializing the pipeline
    pipeline.set_params(**best_params)
    pipeline.fit(train_df['preprocessed_comment'], train_df['toxicity'])          #Training the Model

    #Predicitng on the Validation set
    y_pred = pipeline.predict(val_df['preprocessed_comment'])                   # Making predictions on the val_df['preprocessed_comment']

    #computing the performance useing the compute_performance function
    score= compute_performance(val_df['toxicity'], y_pred)                      #calling the compute_performance function


    print(score)

    #saving the model and

    save_model(pipeline, model_dir)
    # Now Zip Model to share it
    zip_directory(model_dir, MODEL_Gen_File)
    model_gdrive_link = get_gdrive_link(MODEL_Gen_File)
    print(model_gdrive_link)
    get_shareable_link(model_gdrive_link)
    return model_gdrive_link

# %%
 best_params = {
        'naive_bayes__alpha': 0.0010454648682604534,
        'naive_bayes__fit_prior': False,
    }
model_gdrive_link = train_Gen(train_file, val_file, MODEL_Gen_DIRECTORY)
# Out:
# Preprocessing train data:   0%|          | 0/8699 [00:00<?, ?it/s]
# Preprocessing val data:   0%|          | 0/2920 [00:00<?, ?it/s]
# Accuracy: 0.7407534246575342
# Recall (macro): 0.5083124843697095
# Precision (macro): 0.5064525354781603
# F1 Score (macro): 0.5050708939976601
# Confusion Matrix:
# [[2089  448]
#  [ 309   74]]
# 0.5050708939976601
# Directory 'gdrive/MyDrive/./CE807-24-SP/Assignment/model/2314555/Model_Gen' already exists.
# Saved model to  gdrive/MyDrive/./CE807-24-SP/Assignment/model/2314555/Model_Gen/model.sav
# Created a zip file gdrive/MyDrive/./CE807-24-SP/Assignment/model/2314555/Model_Gen.zip
# https://drive.google.com/file/d/1Mh2XmDDXO5D-Vs8XI-6Uz41niONiKauC/view?usp=sharing

# %% [markdown]
# # ***Hyperparameter Tunning of the Naive Bayes***

# %%
import optuna

# Reading the train and validation file
train_df = pd.read_csv(train_file)
val_df = pd.read_csv(val_file)

tqdm.pandas(desc="Preprocessing train data")
train_df['preprocessed_comment'] = train_df['comment'].progress_apply(preprocess_text)
tqdm.pandas(desc="Preprocessing val data")
val_df['preprocessed_comment'] = val_df['comment'].progress_apply(preprocess_text)

# Initialize the vectorizer
vectorizer = TfidfVectorizer()

# Fit the vectorizer on the training data and transform the training data
train_features = vectorizer.fit_transform(train_df['preprocessed_comment'])

# Transform the validation data using the fitted vectorizer
val_features = vectorizer.transform(val_df['preprocessed_comment'])

# Define the Naive Bayes model with TF-IDF vectorizer as a pipeline
pipeline = Pipeline([
        ('tfidf', vectorizer),
        ('naive_bayes', MultinomialNB())
    ])

def objective(trial):
        # Define the hyperparameter search space
        alpha = trial.suggest_loguniform('alpha', 1e-10, 1)
        fit_prior = trial.suggest_categorical('fit_prior', [True, False])

        # Set hyperparameters
        pipeline.set_params(naive_bayes__alpha=alpha, naive_bayes__fit_prior=fit_prior)

        # Train the model
        pipeline.fit(train_df['preprocessed_comment'], train_df['toxicity'])

        # Predict on validation set
        y_pred = pipeline.predict(val_df['preprocessed_comment'])

        # Calculate F1 score for optimization
        f1 = f1_score(val_df['toxicity'], y_pred)

        return -f1  # Optuna minimizes the objective

    # Create an Optuna study for optimization
    study = optuna.create_study(direction='minimize')

    # Optimize hyperparameters using the objective function defined above
    study.optimize(objective, n_trials=100)

    # Get the best hyperparameters found during optimization
    best_params = study.best_params
    print('Best hyperparameters:', best_params)

    # Set best hyperparameters to the pipeline
    pipeline.set_params(**best_params)

    # Train the model on the entire training data
    pipeline.fit(train_df['preprocessed_comment'], train_df['toxicity'])

    # Predict on validation data
    y_pred = pipeline.predict(val_df['preprocessed_comment'])

    # Evaluate the model
    accuracy = accuracy_score(val_df['toxicity'], y_pred)
    recall = recall_score(val_df['toxicity'], y_pred)
    precision = precision_score(val_df['toxicity'], y_pred)
    f1 = f1_score(val_df['toxicity'], y_pred)

    print('Accuracy:', accuracy)
    print('Recall:', recall)
    print('Precision:', precision)
    print('F1 Score:', f1)

# %% [markdown]
# ## Testing Method generative (Naive Bayes) Code

# %%
def test_Gen(test_file, MODEL_PATH,model_gdrive_link):
    print('\n Start by downloading model')
    # Frist Get model from the link
    model_gdrive_link = get_gdrive_link('https://drive.google.com/file/d/1Mh2XmDDXO5D-Vs8XI-6Uz41niONiKauC/view?usp=sharing')

    # These two are temporary directory and file
    test_model_file = MODEL_PATH+'/test.zip'
    test_model_path = MODEL_PATH+'/test/'

    # Now download and unzip the model file
    download_zip_file_from_link(model_gdrive_link,test_model_file)
    print('Model downloaded to', test_model_file)
    unzip_file(test_model_file, test_model_path)
    print('\n Model is downloaded to ',test_model_path)



    test_df=pd.read_csv(test_file)
    print('\n Data is loaded from', test_file)

    #getting the model file name and loading it
    test_model_file=os.path.join(test_model_path,'Model_Gen','model.sav')

    model=load_model(test_model_file)

    #Doing the prediction
    y_pred=model.predict(test_df['comment'])

    # Now save the model output in the same test file
    # Note the name of output column, this is for the discriminative model
    test_df['out_label_model_Gen'] = y_pred

    # Now save the model output in the same output file
    test_df.to_csv(test_file, index=False)
    print('\n Output is save in ', test_file)

    return test_file

# %% [markdown]
# ## Method Generative End

# %% [markdown]
# # Method Discriminative Start
#
# This section includes all details of your Method 2.
#
# *   Data reading
# *   Data clearning, if any
# *   Convert data to vector/tokenization/vectorization
# *   Model Declaration/Initialization/building
# *   Training and validation of the model using training and validation dataset
# *   Save the trained model
# *   Load and Test the model on testing set
# *   Save the output of the model

# %% [markdown]
# ## Training Method Discriminative Code

# %% [markdown]
# Importing all Libraries

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.pipeline import Pipeline
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, confusion_matrix
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from sklearn.naive_bayes import MultinomialNB
from tqdm.auto import tqdm


import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# Data Preprocessing and Cleaning

# %%
def preprocess_text(text):
        # Remove specific tokens
        text = text.replace("SDATA_5 :", "").replace("EDATA_5", "").replace("NEWLINE_TOKEN", "")
        # Remove special characters and punctuation marks using regular expressions
        text = re.sub(r'[^\w\s]', '', text)
        # Remove URLs, email addresses, and phone numbers
        text = re.sub(r"http\S+|www\S+|\S+@\S+|\d{10}", "", text)
        # Remove numbers
        text = re.sub(r"\d+", "", text)
        # Remove non-ASCII characters
        text = text.encode("ascii", "ignore").decode()
        # Convert the text to lowercase
        text = text.lower()
        # Remove extra white spaces
        text = re.sub(r"\s+", " ", text)
        # Tokenize the text
        tokens = nltk.word_tokenize(text)
        # Remove stop words
        stop_words = set(stopwords.words("english"))
        tokens = [word for word in tokens if word not in stop_words]
        # Apply lemmatization
        lemmatizer = WordNetLemmatizer()
        tokens = [lemmatizer.lemmatize(word) for word in tokens]
        # Join the tokens back into a single string
        preprocessed_text = " ".join(tokens)
        return preprocessed_text

# %% [markdown]
# # ***Training the Descriminative Model***

# %%
def train_dis(train_file, val_file, model_dir):
    # Getting the train and validation datasets
    train_df = pd.read_csv(train_file)  # Read the training data file
    val_df = pd.read_csv(val_file)  # Read the validation data file

    # Preprocess the text
    tqdm.pandas(desc="Preprocessing train data")  # Display progress bar while preprocessing training data
    train_df['preprocessed_comment'] = train_df['comment'].progress_apply(preprocess_text)  # Apply text preprocessing to training comments
    tqdm.pandas(desc="Preprocessing val data")  # Display progress bar while preprocessing validation data
    val_df['preprocessed_comment'] = val_df['comment'].progress_apply(preprocess_text)  # Apply text preprocessing to validation comments

    # Define the best hyperparameters found during hyperparameter tuning
    best_params = {
        "objective": "reg:squarederror",  # Objective function for regression
        #"objective": "binary:logistic",  # Objective function for binary classification
        'n_estimators': 859,  # Number of boosting rounds
        'learning_rate': 0.09069799936088908,  # Learning rate
        'max_depth': 10,  # Maximum depth of a tree
        'subsample': 0.7415235437197126,  # Subsample ratio of the training instances
        'colsample_bytree': 0.5241592558794433,  # Subsample ratio of columns
        'min_child_weight': 2  # Minimum sum of instance weight needed in a child
    }

#Not too good hyperparameter
#     best_params = {
#     'n_estimators': 881,
#     'learning_rate': 0.08910550329006076,
#     'max_depth': 10,
#     'subsample': 0.7492147652962634,
#     'colsample_bytree': 0.7729820169038697,
#     'min_child_weight': 1
# }


    # Create an instance of TfidfVectorizer
    vectorizer = TfidfVectorizer()

    # Fit the vectorizer on the training data and transform the training data
    train_features = vectorizer.fit_transform(train_df['preprocessed_comment'])

    # Transform the validation data using the fitted vectorizer
    val_features = vectorizer.transform(val_df['preprocessed_comment'])

    # Create an instance of XGBClassifier with the best parameters
    model = XGBClassifier(**best_params, tree_method='auto')

    # Fit the model on the training features and labels
    model.fit(train_features, train_df['toxicity'])

    # Predict on the validation features
    val_pred = model.predict(val_features)

    # Compute performance metrics
    score = compute_performance(val_df['toxicity'], val_pred)

    print(score)

    # Model is working fine, so save model
    save_model(model, model_dir)

    # Now Zip Model to share it
    zip_directory(model_dir, MODEL_Dis_File)

    # Get a shareable link for the zipped model file
    model_gdrive_link = get_gdrive_link(MODEL_Dis_File)

    print(model_gdrive_link)
    get_shareable_link(model_gdrive_link)

    return model_gdrive_link

# %% [markdown]
# # ***Hyperparameter tunning for XGBoost***

# %%
# !pip install optuna   #Downloading Optuna for hyperparameter tunning
# Out:
# Collecting optuna
#   Downloading optuna-3.6.1-py3-none-any.whl (380 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.1/380.1 kB 2.6 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.1-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 13.5 MB/s eta 0:00:00
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.29)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.1)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.3-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.0.3)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.5)
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.3 alembic-1.13.1 colorlog-6.8.2 optuna-3.6.1

# %%
train_df = pd.read_csv(train_file)
val_df = pd.read_csv(val_file)

    # Preprocess the text
tqdm.pandas(desc="Preprocessing train data")
train_df['preprocessed_comment'] = train_df['comment'].progress_apply(preprocess_text)
tqdm.pandas(desc="Preprocessing val data")
val_df['preprocessed_comment'] = val_df['comment'].progress_apply(preprocess_text)
def objective(trial):
    # Define the hyperparameter search space
    params = {
        "objective": "binary:logistic",  # Objective function for binary classification
        "n_estimators": trial.suggest_int('n_estimators', 100, 1000),  # Number of trees
        "verbosity": 0,  # Verbosity level of XGBoost
        "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
        "max_depth": trial.suggest_int('max_depth', 3, 10),  # Maximum tree depth
        "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
        "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
        "min_child_weight": trial.suggest_int('min_child_weight', 1, 10),  # Minimum sum of instance weight needed in a child
    }


    vectorizer = TfidfVectorizer()

    # Fit the vectorizer on the training data and transform the training data
    train_features = vectorizer.fit_transform(train_df['preprocessed_comment'])

    # Transform the validation data using the fitted vectorizer
    val_features = vectorizer.transform(val_df['preprocessed_comment'])
    # Instantiate the XGBoost model with hyperparameters
    model = xgb.XGBClassifier(**params)

    # Train the model on training data
    model.fit(train_features, train_df['toxicity'], verbose=False)

    # Make predictions on validation data
    val_pred = model.predict(val_features)

    # Calculate the F1 score as the objective metric
    f1 = f1_score(val_df['toxicity'], val_pred)

    # Optuna minimizes the objective, so return negative F1 score
    return -f1

# Create an Optuna study for optimization
study = optuna.create_study(direction='minimize')

# Optimize hyperparameters using the objective function defined above
study.optimize(objective, n_trials=100)

# Get the best hyperparameters found during optimization
best_params = study.best_params
print('Best hyperparameters:', best_params)

# Train the XGBoost model using the best hyperparameters
model = xgb.XGBClassifier(**best_params)
model.fit(train_features, train_df['toxicity'], verbose=False)

# Make predictions on validation data using the trained model
val_pred = model.predict(val_features)

# Calculate various evaluation metrics
accuracy = accuracy_score(val_df['toxicity'], val_pred)
recall = recall_score(val_df['toxicity'], val_pred, average='macro')
precision = precision_score(val_df['toxicity'], val_pred, average='macro')
f1 = f1_score(val_df['toxicity'], val_pred, average='macro')

# Print the evaluation metrics
print('Accuracy:', accuracy)
print('Recall (macro):', recall)
print('Precision (macro):', precision)
print('F1 Score (macro):', f1)

# Compute and print the confusion matrix
labels = np.unique(np.concatenate((val_df['toxicity'], val_pred)))
cm = confusion_matrix(val_df['toxicity'], val_pred, labels=labels)
print('Confusion Matrix:')
print(cm)
# Out:
# Preprocessing train data: 100%|██████████| 8699/8699 [00:20<00:00, 425.46it/s]
# Preprocessing val data: 100%|██████████| 2920/2920 [00:04<00:00, 688.88it/s]
# [I 2024-04-23 09:02:19,175] A new study created in memory with name: no-name-63ef7ab2-4d36-44c0-b5ec-9c02d690aae0
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 09:03:04,735] Trial 0 finished with value: -0.0 and parameters: {'n_estimators': 949, 'learning_rate': 0.002227765284434695, 'max_depth': 5, 'subsample': 0.2345170513330086, 'colsample_bytree': 0.33477507467402645, 'min_child_weight': 1}. Best is trial 0 with value: -0.0.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 09:03:52,618] Trial 1 finished with value: -0.0 and parameters: {'n_estimators': 939, 'learning_rate': 0.002041109300072065, 'max_depth': 8, 'subsample': 0.5835982067556804, 'colsample_bytree': 0.2769383146938659, 'min_child_weight': 9}. Best is trial 0 with value: -0.0.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 09:04:07,703] Trial 2 finished with value: -0.0 and parameters: {'n_estimators': 245, 'learning_rate': 0.0796499898269319, 'max_depth': 10, 'subsample': 0.976373992492607, 'colsample_bytree': 0.11844193224072873, 'min_child_weight': 4}. Best is trial 0 with value: -0.0.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 09:04:32,798] Trial 3 finished with value: -0.0 and parameters: {'n_estimators': 241, 'learning_rate': 0.010747443597167058, 'max_depth': 10, 'subsample': 0.6948693753416141, 'colsample_bytree': 0.5563075326825972, 'min_child_weight': 7}. Best is trial 0 with value: -0.0.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 09:06:11,518] Trial 4 finished with value: -0.0 and parameters: {'n_estimators': 960, 'learning_rate': 0.012325093069851082, 'max_depth': 7, 'subsample': 0.31053267502948106, 'colsample_bytree': 0.5171743309284293, 'min_child_weight': 7}. Best is trial 0 with value: -0.0.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 09:07:02,650] Trial 5 finished with value: -0.0 and parameters: {'n_estimators': 490, 'learning_rate': 0.033456873873157045, 'max_depth': 8, 'subsample': 0.8149129892204133, 'colsample_bytree': 0.8138133616557062, 'min_child_weight': 7}. Best is trial 0 with value: -0.0.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 09:07:21,352] Trial 6 finished with value: -0.0 and parameters: {'n_estimators': 438, 'learning_rate': 0.0010486140539306336, 'max_depth': 5, 'subsample': 0.985389103057263, 'colsample_bytree': 0.35268554593639445, 'min_child_weight': 4}. Best is trial 0 with value: -0.0.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 09:08:00,958] Trial 7 finished with value: -0.0 and parameters: {'n_estimators': 663, 'learning_rate': 0.002291607126358342, 'max_depth': 10, 'subsample': 0.1683321413866984, 'colsample_bytree': 0.31622798751174963, 'min_child_weight': 5}. Best is trial 0 with value: -0.0.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 09:08:22,286] Trial 8 finished with value: -0.0 and parameters: {'n_estimators': 685, 'learning_rate': 0.05955919329078069, 'max_depth': 4, 'subsample': 0.1815519598155855, 'colsample_bytree': 0.13703163201389024, 'min_child_weight': 7}. Best is trial 0 with value: -0.0.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 09:09:00,702] Trial 9 finished with value: -0.0 and parameters: {'n_estimators': 224, 'learning_rate': 0.021029500067319625, 'max_depth': 10, 'subsample': 0.2137272262081915, 'colsample_bytree': 0.9846808916188629, 'min_child_weight': 5}. Best is trial 0 with value: -0.0.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 09:09:37,084] Trial 10 finished with value: -0.0 and parameters: {'n_estimators': 803, 'learning_rate': 0.00497063683659048, 'max_depth': 3, 'subsample': 0.4008126436590982, 'colsample_bytree': 0.5965368109603764, 'min_child_weight': 1}. Best is trial 0 with value: -0.0.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 09:10:23,444] Trial 11 finished with value: -0.0 and parameters: {'n_estimators': 973, 'learning_rate': 0.0031765416179708383, 'max_depth': 6, 'subsample': 0.5119082433273138, 'colsample_bytree': 0.3498334602539881, 'min_child_weight': 10}. Best is trial 0 with value: -0.0.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 09:12:01,814] Trial 12 finished with value: -0.0 and parameters: {'n_estimators': 823, 'learning_rate': 0.0010337721506760622, 'max_depth': 8, 'subsample': 0.5931755034930696, 'colsample_bytree': 0.25231604114037953, 'min_child_weight': 1}. Best is trial 0 with value: -0.0.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 09:12:56,470] Trial 13 finished with value: -0.0 and parameters: {'n_estimators': 858, 'learning_rate': 0.004243376169621707, 'max_depth': 6, 'subsample': 0.4515731758994622, 'colsample_bytree': 0.47658707491214913, 'min_child_weight': 10}. Best is trial 0 with value: -0.0.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 09:13:55,589] Trial 14 finished with value: -0.0 and parameters: {'n_estimators': 1000, 'learning_rate': 0.0017231302849904126, 'max_depth': 8, 'subsample': 0.6343957788146448, 'colsample_bytree': 0.2179225573642191, 'min_child_weight': 3}. Best is trial 0 with value: -0.0.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 09:14:20,613] Trial 15 finished with value: -0.0 and parameters: {'n_estimators': 642, 'learning_rate': 0.00565383393109963, 'max_depth': 5, 'subsample': 0.32683944544466503, 'colsample_bytree': 0.4373571011499719, 'min_child_weight': 9}. Best is trial 0 with value: -0.0.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 09:15:53,958] Trial 16 finished with value: -0.0 and parameters: {'n_estimators': 870, 'learning_rate': 0.001872970875791847, 'max_depth': 7, 'subsample': 0.7566678302290462, 'colsample_bytree': 0.6898406089567768, 'min_child_weight': 3}. Best is trial 0 with value: -0.0.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 09:15:59,458] Trial 17 finished with value: -0.0 and parameters: {'n_estimators': 361, 'learning_rate': 0.0071206775642649245, 'max_depth': 3, 'subsample': 0.11157320031676608, 'colsample_bytree': 0.22767392006958204, 'min_child_weight': 8}. Best is trial 0 with value: -0.0.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 09:16:37,963] Trial 18 finished with value: -0.0 and parameters: {'n_estimators': 778, 'learning_rate': 0.0027922257195082912, 'max_depth': 5, 'subsample': 0.5030929962795134, 'colsample_bytree': 0.3771827049603825, 'min_child_weight': 2}. Best is trial 0 with value: -0.0.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 09:16:48,879] Trial 19 finished with value: -0.0 and parameters: {'n_estimators': 107, 'learning_rate': 0.0014875117151131744, 'max_depth': 9, 'subsample': 0.354113856845359, 'colsample_bytree': 0.6461423257771625, 'min_child_weight': 6}. Best is trial 0 with value: -0.0.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 09:17:14,639] Trial 20 finished with value: -0.0 and parameters: {'n_estimators': 748, 'learning_rate': 0.003513358612459801, 'max_depth': 4, 'subsample': 0.8405358133501257, 'colsample_bytree': 0.4285025572708739, 'min_child_weight': 9}. Best is trial 0 with value: -0.0.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 09:17:46,292] Trial 21 finished with value: -0.0 and parameters: {'n_estimators': 568, 'learning_rate': 0.057596327835831296, 'max_depth': 9, 'subsample': 0.9402065558166334, 'colsample_bytree': 0.11242802099797122, 'min_child_weight': 3}. Best is trial 0 with value: -0.0.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 09:18:40,343] Trial 22 finished with value: -0.0 and parameters: {'n_estimators': 901, 'learning_rate': 0.01701783017137038, 'max_depth': 9, 'subsample': 0.8929818570996773, 'colsample_bytree': 0.18035318926193744, 'min_child_weight': 4}. Best is trial 0 with value: -0.0.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 09:18:57,662] Trial 23 finished with value: -0.0 and parameters: {'n_estimators': 264, 'learning_rate': 0.03832719094672966, 'max_depth': 7, 'subsample': 0.6918169199107602, 'colsample_bytree': 0.29088160380600814, 'min_child_weight': 2}. Best is trial 0 with value: -0.0.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 09:19:12,680] Trial 24 finished with value: -0.0 and parameters: {'n_estimators': 381, 'learning_rate': 0.07836033216666191, 'max_depth': 9, 'subsample': 0.2690145658776767, 'colsample_bytree': 0.1210117611099415, 'min_child_weight': 6}. Best is trial 0 with value: -0.0.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 09:19:19,646] Trial 25 finished with value: -0.0 and parameters: {'n_estimators': 106, 'learning_rate': 0.00762347752118879, 'max_depth': 6, 'subsample': 0.431010748554353, 'colsample_bytree': 0.2724606259471605, 'min_child_weight': 4}. Best is trial 0 with value: -0.0.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 09:19:50,267] Trial 26 finished with value: -0.02843601895734597 and parameters: {'n_estimators': 551, 'learning_rate': 0.09820152156292587, 'max_depth': 8, 'subsample': 0.7618934281872145, 'colsample_bytree': 0.17671745538578934, 'min_child_weight': 2}. Best is trial 26 with value: -0.02843601895734597.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 09:20:26,670] Trial 27 finished with value: -0.0 and parameters: {'n_estimators': 582, 'learning_rate': 0.021355906835994705, 'max_depth': 8, 'subsample': 0.5937816656805803, 'colsample_bytree': 0.18980552072513404, 'min_child_weight': 2}. Best is trial 26 with value: -0.02843601895734597.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 09:21:33,654] Trial 28 finished with value: -0.0 and parameters: {'n_estimators': 726, 'learning_rate': 0.00138284668653888, 'max_depth': 7, 'subsample': 0.7380150510894278, 'colsample_bytree': 0.383591922580357, 'min_child_weight': 1}. Best is trial 26 with value: -0.02843601895734597.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 09:22:06,191] Trial 29 finished with value: -0.023809523809523805 and parameters: {'n_estimators': 913, 'learning_rate': 0.09283720928419151, 'max_depth': 4, 'subsample': 0.6509109730052212, 'colsample_bytree': 0.3024649749342886, 'min_child_weight': 2}. Best is trial 26 with value: -0.02843601895734597.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 09:22:40,313] Trial 30 finished with value: -0.0 and parameters: {'n_estimators': 929, 'learning_rate': 0.03593800652844798, 'max_depth': 4, 'subsample': 0.6511116419345463, 'colsample_bytree': 0.2907534931157739, 'min_child_weight': 2}. Best is trial 26 with value: -0.02843601895734597.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 09:23:17,533] Trial 31 finished with value: -0.022779043280182234 and parameters: {'n_estimators': 913, 'learning_rate': 0.09246802877619548, 'max_depth': 5, 'subsample': 0.5667223832803395, 'colsample_bytree': 0.1935475027312455, 'min_child_weight': 1}. Best is trial 26 with value: -0.02843601895734597.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 09:23:48,916] Trial 32 finished with value: -0.03333333333333333 and parameters: {'n_estimators': 839, 'learning_rate': 0.09795751526868644, 'max_depth': 5, 'subsample': 0.7885722351558097, 'colsample_bytree': 0.17482715349653705, 'min_child_weight': 1}. Best is trial 32 with value: -0.03333333333333333.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 09:24:15,819] Trial 33 finished with value: -0.0049382716049382715 and parameters: {'n_estimators': 856, 'learning_rate': 0.08951687636230732, 'max_depth': 4, 'subsample': 0.8117938996242483, 'colsample_bytree': 0.18551682426770016, 'min_child_weight': 1}. Best is trial 32 with value: -0.03333333333333333.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 09:24:38,570] Trial 34 finished with value: -0.0 and parameters: {'n_estimators': 619, 'learning_rate': 0.05733977549780837, 'max_depth': 5, 'subsample': 0.7511090558713929, 'colsample_bytree': 0.16268981974595215, 'min_child_weight': 2}. Best is trial 32 with value: -0.03333333333333333.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 09:24:59,291] Trial 35 finished with value: -0.014563106796116504 and parameters: {'n_estimators': 913, 'learning_rate': 0.09320522309915766, 'max_depth': 3, 'subsample': 0.5449236048977237, 'colsample_bytree': 0.23295248136330887, 'min_child_weight': 1}. Best is trial 32 with value: -0.03333333333333333.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 09:25:23,545] Trial 36 finished with value: -0.0 and parameters: {'n_estimators': 714, 'learning_rate': 0.04426349256371916, 'max_depth': 6, 'subsample': 0.6858124045801156, 'colsample_bytree': 0.10526154178609104, 'min_child_weight': 3}. Best is trial 32 with value: -0.03333333333333333.
# ...
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 10:23:42,508] Trial 88 finished with value: -0.009523809523809525 and parameters: {'n_estimators': 989, 'learning_rate': 0.05863631266797739, 'max_depth': 10, 'subsample': 0.9577131976964322, 'colsample_bytree': 0.6579670800814418, 'min_child_weight': 6}. Best is trial 73 with value: -0.04899777282850779.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 10:26:46,602] Trial 89 finished with value: -0.023584905660377353 and parameters: {'n_estimators': 936, 'learning_rate': 0.05293119074133181, 'max_depth': 10, 'subsample': 0.8429427134715028, 'colsample_bytree': 0.7098990923464159, 'min_child_weight': 1}. Best is trial 73 with value: -0.04899777282850779.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 10:28:38,588] Trial 90 finished with value: -0.009975062344139652 and parameters: {'n_estimators': 848, 'learning_rate': 0.041619218566647964, 'max_depth': 9, 'subsample': 0.8138146200509436, 'colsample_bytree': 0.6141471720148217, 'min_child_weight': 2}. Best is trial 73 with value: -0.04899777282850779.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 10:30:56,604] Trial 91 finished with value: -0.041379310344827586 and parameters: {'n_estimators': 827, 'learning_rate': 0.07695393871651429, 'max_depth': 10, 'subsample': 0.7485446377965318, 'colsample_bytree': 0.7634358982204539, 'min_child_weight': 2}. Best is trial 73 with value: -0.04899777282850779.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 10:33:17,815] Trial 92 finished with value: -0.027906976744186046 and parameters: {'n_estimators': 827, 'learning_rate': 0.07521116137821732, 'max_depth': 10, 'subsample': 0.8928093714390096, 'colsample_bytree': 0.8035943508554434, 'min_child_weight': 2}. Best is trial 73 with value: -0.04899777282850779.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 10:36:13,832] Trial 93 finished with value: -0.052980132450331126 and parameters: {'n_estimators': 881, 'learning_rate': 0.08910550329006076, 'max_depth': 10, 'subsample': 0.7492147652962634, 'colsample_bytree': 0.7729820169038697, 'min_child_weight': 1}. Best is trial 93 with value: -0.052980132450331126.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 10:38:44,956] Trial 94 finished with value: -0.03131991051454139 and parameters: {'n_estimators': 890, 'learning_rate': 0.08942629438938014, 'max_depth': 10, 'subsample': 0.7452320295639565, 'colsample_bytree': 0.8211205489390603, 'min_child_weight': 2}. Best is trial 93 with value: -0.052980132450331126.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 10:41:20,721] Trial 95 finished with value: -0.023584905660377353 and parameters: {'n_estimators': 794, 'learning_rate': 0.06628355570607664, 'max_depth': 9, 'subsample': 0.7293365692443206, 'colsample_bytree': 0.8358878452390913, 'min_child_weight': 1}. Best is trial 93 with value: -0.052980132450331126.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 10:43:28,389] Trial 96 finished with value: -0.03571428571428572 and parameters: {'n_estimators': 869, 'learning_rate': 0.08967537572216447, 'max_depth': 10, 'subsample': 0.6952805666740407, 'colsample_bytree': 0.7763244193371184, 'min_child_weight': 3}. Best is trial 93 with value: -0.052980132450331126.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 10:45:32,444] Trial 97 finished with value: -0.013793103448275862 and parameters: {'n_estimators': 911, 'learning_rate': 0.080173099268013, 'max_depth': 10, 'subsample': 0.6806324444220673, 'colsample_bytree': 0.782463698203707, 'min_child_weight': 4}. Best is trial 93 with value: -0.052980132450331126.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 10:47:53,172] Trial 98 finished with value: -0.023696682464454975 and parameters: {'n_estimators': 866, 'learning_rate': 0.057976980199321154, 'max_depth': 10, 'subsample': 0.7068302003469867, 'colsample_bytree': 0.8812812429396236, 'min_child_weight': 3}. Best is trial 93 with value: -0.052980132450331126.
# <ipython-input-172-f2f39509b0e4>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform('learning_rate', 0.001, 0.1),  # Learning rate
# <ipython-input-172-f2f39509b0e4>:18: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform('subsample', 0.1, 1.0),  # Subsample ratio of the training instances
# <ipython-input-172-f2f39509b0e4>:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform('colsample_bytree', 0.1, 1.0),  # Subsample ratio of columns
# [I 2024-04-23 10:50:50,708] Trial 99 finished with value: -0.0 and parameters: {'n_estimators': 950, 'learning_rate': 0.005613167761598393, 'max_depth': 10, 'subsample': 0.7774227149191357, 'colsample_bytree': 0.7710086909786684, 'min_child_weight': 3}. Best is trial 93 with value: -0.052980132450331126.
# Best hyperparameters: {'n_estimators': 881, 'learning_rate': 0.08910550329006076, 'max_depth': 10, 'subsample': 0.7492147652962634, 'colsample_bytree': 0.7729820169038697, 'min_child_weight': 1}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-172-f2f39509b0e4> in <cell line: 58>()
#      56 # Train the XGBoost model using the best hyperparameters
#      57 model = xgb.XGBClassifier(**best_params)
# ---> 58 model.fit(train_features, train_df['toxicity'], verbose=False)
#      59
#      60 # Make predictions on validation data using the trained model
#
# NameError: name 'train_features' is not defined

# %%
# Call the train_dis function and pass the best_params dictionary
model_gdrive_link = train_dis(train_file, val_file, MODEL_Dis_DIRECTORY)

#model_gdrive_link = train_Gen(train_file, val_file, MODEL_Gen_DIRECTORY)
# Out:
# Preprocessing train data:   0%|          | 0/8699 [00:00<?, ?it/s]
# Preprocessing val data:   0%|          | 0/2920 [00:00<?, ?it/s]
# Accuracy: 0.8267123287671233
# Recall (macro): 0.5067939662704763
# Precision (macro): 0.5134549026881271
# F1 Score (macro): 0.5018872402600467
# Confusion Matrix:
# [[2386  151]
#  [ 355   28]]
# 0.5018872402600467
# Directory 'gdrive/MyDrive/./CE807-24-SP/Assignment/model/2314555/Model_Dis' already exists.
# Saved model to  gdrive/MyDrive/./CE807-24-SP/Assignment/model/2314555/Model_Dis/model.sav
# Created a zip file gdrive/MyDrive/./CE807-24-SP/Assignment/model/2314555/Model_Dis.zip
# https://drive.google.com/file/d/1-9cKtPSpzhXg34spwoFiY8iZ5g2ugtv1/view?usp=sharing

# %% [markdown]
# ## Testing Method Discriminative Code

# %%
def test_dis(test_file, MODEL_PATH,model_gdrive_link):

    print('\n Start by downloading model')
    # Frist Get model from the link
    model_gdrive_link = get_gdrive_link('https://drive.google.com/file/d/1-9cKtPSpzhXg34spwoFiY8iZ5g2ugtv1/view?usp=sharing')

    # These two are temporary directory and file
    test_model_file = MODEL_PATH+'/test.zip'
    test_model_path = MODEL_PATH+'/test/'

    # Now download and unzip the model file
    download_zip_file_from_link(model_gdrive_link,test_model_file)
    print('Model downloaded to', test_model_file)
    unzip_file(test_model_file, test_model_path)
    print('\n Model is downloaded to ',test_model_path)



    test_df=pd.read_csv(test_file)
    print('\n Data is loaded from', test_file)

    #getting the model file name and loading it
    test_model_file=os.path.join(test_model_path,'Model_Dis','model.sav')

    model=load_model(test_model_file)

    #Doing the prediction
    y_pred=model.predict(test_df['comment'])

    # Now save the model output in the same test file
    # Note the name of output column, this is for the discriminative model
    test_df['out_label_model_Dis'] = y_pred

    # Now save the model output in the same output file
    test_df.to_csv(test_file, index=False)
    print('\n Output is save in ', test_file)

    return test_file

# %% [markdown]
# ## Discriminative Method  End

# %% [markdown]
# # Other Method/model Start

# %%
import argparse

# %%
# Define argparse-like function
def parse_arguments(option):
    parser = argparse.ArgumentParser(description='Process some integers.')
    parser.add_argument('--option', '-o',  type=str, default=option, help='Description of your option.')
    args = parser.parse_args(args=[])
    return args

# Function to perform some action based on selected option
def perform_action(option):
    print("Performing action with option:", option)

    if option == '0':
      print('\n Okay Exiting!!! ')

    elif option == '1':
      print('\n Training Generative Model')
      model_gdrive_link = train_Gen(train_file,val_file,MODEL_Gen_DIRECTORY)
      print('Make sure to pass model URL in Testing',model_gdrive_link)

    elif option == '2':
      print('\n\n Pass the URL Not Variable !!!')
      print('\n Testing Generative Model')
      model_gen_url = 'https://drive.google.com/file/d/1Mh2XmDDXO5D-Vs8XI-6Uz41niONiKauC/view?usp=sharing'
      test_Gen(test_file, MODEL_PATH, model_gen_url)

    elif option == '3':
      print('\n Training Disciminative Model')
      model_gdrive_link = train_dis(train_file,val_file,MODEL_Dis_DIRECTORY)
      print('Make sure to pass model URL in Testing',model_gdrive_link)
      print('\n\n Pass the URL Not Variable !!!')

    elif option == '4':
      print('\n\n Pass the URL Not Variable !!!')
      print('\n Testing Disciminative Model')
      model_dis_url = 'https://drive.google.com/file/d/1-9cKtPSpzhXg34spwoFiY8iZ5g2ugtv1/view?usp=sharing'
      test_dis(test_file, MODEL_PATH, model_dis_url)

    else:
      print('Wrong Option Selected. \n\nPlease select Correct option')
      main()


def main():

    # Get option from user input
    user_option = input("0. To Exit Code\n"
                     "1. Train Model Generative\n"
                    "2. Test Model Generative\n"
                    "3. Train Model Discriminative\n"
                    "4. Test Model Discriminative\n"
                    "Enter your option: ")

    args = parse_arguments(user_option)
    option = args.option
    perform_action(option)

# %%
main()
# Out:
# 0. To Exit Code
# 1. Train Model Generative
# 2. Test Model Generative
# 3. Train Model Discriminative
# 4. Test Model Discriminative
# Enter your option: 4
# Performing action with option: 4
#
#
#  Pass the URL Not Variable !!!
#
#  Testing Disciminative Model
#
#  Start by downloading model
# Invalid Google Drive URL.
# Model downloaded to gdrive/MyDrive/./CE807-24-SP/Assignment/model/2314555/test.zip
# Extracted a zip file to gdrive/MyDrive/./CE807-24-SP/Assignment/model/2314555/test/
#
#  Model is downloaded to  gdrive/MyDrive/./CE807-24-SP/Assignment/model/2314555/test/
#
#  Data is loaded from gdrive/MyDrive/./CE807-24-SP/Assignment/data/5/test.csv
# Loaded model from  gdrive/MyDrive/./CE807-24-SP/Assignment/model/2314555/test/Model_Dis/model.sav
#
#  Output is save in  gdrive/MyDrive/./CE807-24-SP/Assignment/data/5/test.csv

# %%
model_dis_url = 'https://drive.google.com/file/d/1-9cKtPSpzhXg34spwoFiY8iZ5g2ugtv1/view?usp=sharing'
test_dis(test_file, MODEL_PATH, model_dis_url)
# Out:
#  Start by downloading model
# Invalid Google Drive URL.
# Model downloaded to gdrive/MyDrive/./CE807-24-SP/Assignment/model/2314555/test.zip
# Extracted a zip file to gdrive/MyDrive/./CE807-24-SP/Assignment/model/2314555/test/
#
#  Model is downloaded to  gdrive/MyDrive/./CE807-24-SP/Assignment/model/2314555/test/
#
#  Data is loaded from gdrive/MyDrive/./CE807-24-SP/Assignment/data/5/test.csv
# Loaded model from  gdrive/MyDrive/./CE807-24-SP/Assignment/model/2314555/test/Model_Dis/model.sav
#
#  Output is save in  gdrive/MyDrive/./CE807-24-SP/Assignment/data/5/test.csv
# 'gdrive/MyDrive/./CE807-24-SP/Assignment/data/5/test.csv'

# %%
model_Gen_url = 'https://drive.google.com/file/d/1--sJNJMLFvAz77HjiB8is8DDHOfY0FBG/view?usp=sharing'
test_Gen(test_file, MODEL_PATH, model_Gen_url)
# Out:
#  Start by downloading model
# Invalid Google Drive URL.
# Model downloaded to gdrive/MyDrive/./CE807-24-SP/Assignment/model/2314555/test.zip
# Extracted a zip file to gdrive/MyDrive/./CE807-24-SP/Assignment/model/2314555/test/
#
#  Model is downloaded to  gdrive/MyDrive/./CE807-24-SP/Assignment/model/2314555/test/
#
#  Data is loaded from gdrive/MyDrive/./CE807-24-SP/Assignment/data/5/test.csv
# Loaded model from  gdrive/MyDrive/./CE807-24-SP/Assignment/model/2314555/test/Model_Gen/model.sav
#
#  Output is save in  gdrive/MyDrive/./CE807-24-SP/Assignment/data/5/test.csv
# 'gdrive/MyDrive/./CE807-24-SP/Assignment/data/5/test.csv'

# %% [markdown]
# ##Other Method/model End

# %%
#CNN
